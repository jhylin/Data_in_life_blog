# %%
import polars as pl

# %%
# PubChem_compound_text_covid-19 clinicaltrials.csv
pc = pl.read_csv("pubchem.csv")
pc.head()
# Out:
# shape: (5, 38)
# ┌─────────┬─────────────┬───────────┬────────┬─────┬──────────┬──────────┬────────────┬────────────┐
# │ cid     ┆ cmpdname    ┆ cmpdsynon ┆ mw     ┆ ... ┆ cidcdate ┆ sidsrcna ┆ depcatg    ┆ annotation │
# │ ---     ┆ ---         ┆ ym        ┆ ---    ┆     ┆ ---      ┆ me       ┆ ---        ┆ ---        │
# │ i64     ┆ str         ┆ ---       ┆ f64    ┆     ┆ i64      ┆ ---      ┆ str        ┆ str        │
# │         ┆             ┆ str       ┆        ┆     ┆          ┆ str      ┆            ┆            │
# ╞═════════╪═════════════╪═══════════╪════════╪═════╪══════════╪══════════╪════════════╪════════════╡
# │ 5280453 ┆ Calcitriol  ┆ calcitrio ┆ 416.6  ┆ ... ┆ 20040916 ┆ A2B      ┆ Chemical   ┆ COVID-19,  │
# │         ┆             ┆ l|32222-0 ┆        ┆     ┆          ┆ Chem|AA  ┆ Vendors|Cu ┆ COVID19,   │
# │         ┆             ┆ 6-3|Rocal ┆        ┆     ┆          ┆ BLOCKS|A ┆ ration     ┆ Coronaviru │
# │         ┆             ┆ trol|...  ┆        ┆     ┆          ┆ aron Che ┆ Effort...  ┆ s, ...     │
# │         ┆             ┆           ┆        ┆     ┆          ┆ mica...  ┆            ┆            │
# │ 9962735 ┆ Ubiquinol   ┆ ubiquinol ┆ 865.4  ┆ ... ┆ 20061025 ┆ 001Chemi ┆ Chemical   ┆ COVID-19,  │
# │         ┆             ┆ |992-78-9 ┆        ┆     ┆          ┆ cal|A2B  ┆ Vendors|Cu ┆ COVID19,   │
# │         ┆             ┆ |ubiquino ┆        ┆     ┆          ┆ Chem|AA  ┆ ration     ┆ Coronaviru │
# │         ┆             ┆ l-10|...  ┆        ┆     ┆          ┆ BLOCKS|A ┆ Effort...  ┆ s, ...     │
# │         ┆             ┆           ┆        ┆     ┆          ┆ ...      ┆            ┆            │
# │ 5961    ┆ Glutamine   ┆ L-glutami ┆ 146.14 ┆ ... ┆ 20040916 ┆ 001Chemi ┆ Chemical   ┆ COVID-19,  │
# │         ┆             ┆ ne|glutam ┆        ┆     ┆          ┆ cal|3B   ┆ Vendors|Cu ┆ COVID19,   │
# │         ┆             ┆ ine|56-85 ┆        ┆     ┆          ┆ Scientif ┆ ration     ┆ Coronaviru │
# │         ┆             ┆ -9|Le...  ┆        ┆     ┆          ┆ ic (Wuha ┆ Effort...  ┆ s, ...     │
# │         ┆             ┆           ┆        ┆     ┆          ┆ n...     ┆            ┆            │
# │ 2244    ┆ Aspirin     ┆ aspirin|A ┆ 180.16 ┆ ... ┆ 20040916 ┆ 001Chemi ┆ Chemical   ┆ COVID-19,  │
# │         ┆             ┆ CETYLSALI ┆        ┆     ┆          ┆ cal|3B   ┆ Vendors|Cu ┆ COVID19,   │
# │         ┆             ┆ CYLIC ACI ┆        ┆     ┆          ┆ Scientif ┆ ration     ┆ Coronaviru │
# │         ┆             ┆ D|50-...  ┆        ┆     ┆          ┆ ic (Wuha ┆ Effort...  ┆ s, ...     │
# │         ┆             ┆           ┆        ┆     ┆          ┆ n...     ┆            ┆            │
# │ 457     ┆ 1-Methylnic ┆ 1-methyln ┆ 137.16 ┆ ... ┆ 20040916 ┆ 001Chemi ┆ Chemical   ┆ COVID-19,  │
# │         ┆ otinamide   ┆ icotinami ┆        ┆     ┆          ┆ cal|3B   ┆ Vendors|Cu ┆ COVID19,   │
# │         ┆             ┆ de|Trigon ┆        ┆     ┆          ┆ Scientif ┆ ration     ┆ Coronaviru │
# │         ┆             ┆ ellin...  ┆        ┆     ┆          ┆ ic (Wuha ┆ Effort...  ┆ s, ...     │
# │         ┆             ┆           ┆        ┆     ┆          ┆ n...     ┆            ┆            │
# └─────────┴─────────────┴───────────┴────────┴─────┴──────────┴──────────┴────────────┴────────────┘

# %%
#print(pc.glimpse())
#pc.columns

# %%
# Check nulls
pc.null_count()
# Out:
# shape: (1, 38)
# ┌─────┬──────────┬─────────────┬─────┬─────┬──────────┬────────────┬─────────┬────────────┐
# │ cid ┆ cmpdname ┆ cmpdsynonym ┆ mw  ┆ ... ┆ cidcdate ┆ sidsrcname ┆ depcatg ┆ annotation │
# │ --- ┆ ---      ┆ ---         ┆ --- ┆     ┆ ---      ┆ ---        ┆ ---     ┆ ---        │
# │ u32 ┆ u32      ┆ u32         ┆ u32 ┆     ┆ u32      ┆ u32        ┆ u32     ┆ u32        │
# ╞═════╪══════════╪═════════════╪═════╪═════╪══════════╪════════════╪═════════╪════════════╡
# │ 0   ┆ 0        ┆ 0           ┆ 0   ┆ ... ┆ 0        ┆ 0          ┆ 0       ┆ 0          │
# └─────┴──────────┴─────────────┴─────┴─────┴──────────┴────────────┴─────────┴────────────┘

# %%
# Check column definitions and annotations in rows

# Change column names
#df.rename({"foo": "apple"})

pc.rename(
    {
        "cmpdname": "Compound_name",
        "cmpdsynonym": "Synonyms",
        # Molecular mass (daltons)
        "mw": "Molecular_weight",
        "mf": "Molecular_formula",
        # Topological polar surface area (angstrom squared)
        "polararea": "Polar_surface_area",
        # Complexity rating for compound
        # Based on Bertz/Hendrickson/Ihlenfeldt formula
        # Rough estimation of how complex a compound is structurally
        "complexity": "Complexity",
        # Predicted octanol-water partition coefficient
        # Measure of hydrophilicity or hydrophobicity of a molecule
        "xlogp": "Partition_coef",
        # Number of heavy atoms e.g. non-H atoms in the compound
        "heavycnt": "Heavy_atom_count",
        # Number of hydrogen bond donors in the compound
        "hbonddonor": "H_bond_donor_count",
        # Number of hydrogen bond acceptors in the compound
        "hbondacc": "H_bond_acceptor_count",
        # Defined as any single-order non-ring bond, 
        # where atoms on either side of the bond are in turn bound to
        # non-terminal heavy atoms (e.g. non-H)
        # Rotation around the bond axis will change overall
        # molecule shape & generates conformers which can be 
        # distinguished by standard spectroscopic methods
        "rotbonds": "Rotatable_bond_count",
        # Exact mass of an isotopic species
        # Obtained by summing masses of individual isotopes of the molecule
        "exactmass": "Exact_mass",
        # Sum of the masses of atoms in a molecule
        # using unbound, ground-state, rest mass of principal (most abundant) isotope
        # for each element instead of isotopic average mass
        "monoisotopicmass": "Monoisotopic_mass",
        # The difference between the number of valence electrons of each atom
        # and the number of electrons the atom is associated with
        # Assumes any shared electrons are equally shared between the two bonded atoms
        "charge": "Formal_charge",
        # Covalently-bonded unit count - a group of atoms connected by covalent bonds,
        # ignoring other bond types (or a single atom without covalent bonds)
        # Number of such units in the compound
        "covalentunitcnt": "Cov-bonded_unit_count",
        # Number of isotopes that are not most abundant for the corresponding chemical elements
        # Isotopes = variants of a chemical element that differ in neutron number
        "isotopeatomcnt": "Isotope_atom_count",
        "totalatomstereocnt": "Total_atom_stereo_count",
        # Atom stereocenter = chiral center = an atom that is attached to 4 different types of atoms
        # or groups of atoms in the tetrahedral arrangement
        # It can either be (R)- or (S)- configurations
        # Some of the compounds e.g. racemic mixtures, have undefined atom stereocenter, where (R/S)-config
        # is not specifically defined.
        # This column is the number of atom stereocenters whose configurations are specifically defined
        "definedatomstereocnt": "Defined_atom_stereo_count",
        # As explained for the Defined_atom_stereo_count, this is the undefined version
        "undefinedatomstereocnt": "Undefined_atoms_stereo_count",
        "totalbondstereocnt": "Total_bond_stereo_count",
        "definedbondstereocnt":
        
        
        
        
          
        
    }
)


 # 'undefinedbondstereocnt',
 # 'pclidcnt',
 # 'gpidcnt',
 # 'meshheadings',
 # 'annothits',
 # 'annothitcnt',
 # 'aids',
 # 'cidcdate',
 # 'sidsrcname',
 # 'depcatg',
 # 'annotation'
# Out:
# shape: (631, 38)
# ┌───────────┬────────────┬────────────┬────────┬─────┬──────────┬──────────┬────────────┬──────────┐
# │ cid       ┆ Compound_n ┆ Synonyms   ┆ mw     ┆ ... ┆ cidcdate ┆ sidsrcna ┆ depcatg    ┆ annotati │
# │ ---       ┆ ame        ┆ ---        ┆ ---    ┆     ┆ ---      ┆ me       ┆ ---        ┆ on       │
# │ i64       ┆ ---        ┆ str        ┆ f64    ┆     ┆ i64      ┆ ---      ┆ str        ┆ ---      │
# │           ┆ str        ┆            ┆        ┆     ┆          ┆ str      ┆            ┆ str      │
# ╞═══════════╪════════════╪════════════╪════════╪═════╪══════════╪══════════╪════════════╪══════════╡
# │ 5280453   ┆ Calcitriol ┆ calcitriol ┆ 416.6  ┆ ... ┆ 20040916 ┆ A2B      ┆ Chemical   ┆ COVID-19 │
# │           ┆            ┆ |32222-06- ┆        ┆     ┆          ┆ Chem|AA  ┆ Vendors|Cu ┆ ,        │
# │           ┆            ┆ 3|Rocaltro ┆        ┆     ┆          ┆ BLOCKS|A ┆ ration     ┆ COVID19, │
# │           ┆            ┆ l|...      ┆        ┆     ┆          ┆ aron Che ┆ Effort...  ┆ Coronavi │
# │           ┆            ┆            ┆        ┆     ┆          ┆ mica...  ┆            ┆ rus, ... │
# │ 9962735   ┆ Ubiquinol  ┆ ubiquinol| ┆ 865.4  ┆ ... ┆ 20061025 ┆ 001Chemi ┆ Chemical   ┆ COVID-19 │
# │           ┆            ┆ 992-78-9|u ┆        ┆     ┆          ┆ cal|A2B  ┆ Vendors|Cu ┆ ,        │
# │           ┆            ┆ biquinol-1 ┆        ┆     ┆          ┆ Chem|AA  ┆ ration     ┆ COVID19, │
# │           ┆            ┆ 0|...      ┆        ┆     ┆          ┆ BLOCKS|A ┆ Effort...  ┆ Coronavi │
# │           ┆            ┆            ┆        ┆     ┆          ┆ ...      ┆            ┆ rus, ... │
# │ 5961      ┆ Glutamine  ┆ L-glutamin ┆ 146.14 ┆ ... ┆ 20040916 ┆ 001Chemi ┆ Chemical   ┆ COVID-19 │
# │           ┆            ┆ e|glutamin ┆        ┆     ┆          ┆ cal|3B   ┆ Vendors|Cu ┆ ,        │
# │           ┆            ┆ e|56-85-9| ┆        ┆     ┆          ┆ Scientif ┆ ration     ┆ COVID19, │
# │           ┆            ┆ Le...      ┆        ┆     ┆          ┆ ic (Wuha ┆ Effort...  ┆ Coronavi │
# │           ┆            ┆            ┆        ┆     ┆          ┆ n...     ┆            ┆ rus, ... │
# │ 2244      ┆ Aspirin    ┆ aspirin|AC ┆ 180.16 ┆ ... ┆ 20040916 ┆ 001Chemi ┆ Chemical   ┆ COVID-19 │
# │           ┆            ┆ ETYLSALICY ┆        ┆     ┆          ┆ cal|3B   ┆ Vendors|Cu ┆ ,        │
# │           ┆            ┆ LIC ACID|5 ┆        ┆     ┆          ┆ Scientif ┆ ration     ┆ COVID19, │
# │           ┆            ┆ 0-...      ┆        ┆     ┆          ┆ ic (Wuha ┆ Effort...  ┆ Coronavi │
# │           ┆            ┆            ┆        ┆     ┆          ┆ n...     ┆            ┆ rus, ... │
# │ ...       ┆ ...        ┆ ...        ┆ ...    ┆ ... ┆ ...      ┆ ...      ┆ ...        ┆ ...      │
# │ 154699467 ┆ Lufotrelvi ┆ Lufotrelvi ┆ 552.5  ┆ ... ┆ 20200929 ┆ AbaChemS ┆ Chemical   ┆ COVID-19 │
# │           ┆ r          ┆ r|PF-07304 ┆        ┆     ┆          ┆ cene|Bin ┆ Vendors|Cu ┆ ,        │
# │           ┆            ┆ 814|Lufotr ┆        ┆     ┆          ┆ dingDB|C ┆ ration     ┆ COVID19, │
# │           ┆            ┆ el...      ┆        ┆     ┆          ┆ hEBI|ChE ┆ Effort...  ┆ Coronavi │
# │           ┆            ┆            ┆        ┆     ┆          ┆ ...      ┆            ┆ rus, ... │
# │ 155903259 ┆ Nirmatrelv ┆ 2628280-40 ┆ 499.5  ┆ ... ┆ 20210501 ┆ AbaChemS ┆ Chemical   ┆ COVID-19 │
# │           ┆ ir         ┆ -8|7R9A5P7 ┆        ┆     ┆          ┆ cene|AbM ┆ Vendors|Cu ┆ ,        │
# │           ┆            ┆ H32|Nirmat ┆        ┆     ┆          ┆ ole Bios ┆ ration     ┆ COVID19, │
# │           ┆            ┆ re...      ┆        ┆     ┆          ┆ cience|A ┆ Effort...  ┆ Coronavi │
# │           ┆            ┆            ┆        ┆     ┆          ┆ ...      ┆            ┆ rus, ... │
# │ 156599206 ┆ hexasodium ┆ NULL       ┆ 1922.0 ┆ ... ┆ 20210922 ┆ TargetMo ┆ Chemical   ┆ COVID-19 │
# │           ┆ ;4-[[(2S,4 ┆            ┆        ┆     ┆          ┆ l        ┆ Vendors    ┆ ,        │
# │           ┆ R)-5-ethox ┆            ┆        ┆     ┆          ┆          ┆            ┆ COVID19, │
# │           ┆ y-...      ┆            ┆        ┆     ┆          ┆          ┆            ┆ Coronavi │
# │           ┆            ┆            ┆        ┆     ┆          ┆          ┆            ┆ rus, ... │
# │ 165360157 ┆ Nangibotid ┆ Nangibotid ┆ 1342.5 ┆ ... ┆ 20221011 ┆ EPA      ┆ Curation   ┆ COVID-19 │
# │           ┆ e          ┆ e|DTXSID20 ┆        ┆     ┆          ┆ DSSTox   ┆ Efforts|Go ┆ ,        │
# │           ┆            ┆ 1336482|20 ┆        ┆     ┆          ┆          ┆ vernmental ┆ COVID19, │
# │           ┆            ┆ 14...      ┆        ┆     ┆          ┆          ┆ Or...      ┆ Coronavi │
# │           ┆            ┆            ┆        ┆     ┆          ┆          ┆            ┆ rus, ... │
# └───────────┴────────────┴────────────┴────────┴─────┴──────────┴──────────┴────────────┴──────────┘
